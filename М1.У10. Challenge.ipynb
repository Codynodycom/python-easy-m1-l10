# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны три числа (А, B, C) типа данных str.
#
# Программа должна перевести все числа в тип данных int и вывести их на экран.
#
# Пример входных данных:
#
# - "432"
# - "754"
# - "-12"
#
# Пример выходных данных:
#
# - 432
# - 754
# - -12

# %%
A = input('->')
B = input('->')
C = input('->')

# твой код
print(A, B, C)
# Out:
# Тебя зовут Бобби

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны три числа (А, B, C) типа данных str.
#
# Программа должна перевести все числа в тип данных int после чего сложить их и поделить на число C, результат вывести на экран.
#
# Пример входных данных:
#
# - "19"
# - "894"
# - "3"
#
# Пример выходных данных:
#
# - 305,333...

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны пять чисел (А, B, C, D, F) типа данных str.
#
# Программа должна перевести все числа в тип данных float и вывести на экран сумму этих чисел.
#
# Пример входных данных:
#
# - "2.999"
# - "74.1"
# - "3211"
# - "-12.3"
# - "-134.12"
#
# Пример выходных данных:
#
# - 3141.679

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано два числа (А, B) типа данных int.
#
# Программа должна вывести три строки где:
# - Первая строка содержит сумму этих двух чисел
# - Вторая строка содержит разность этих двух чисел (А - B)
# - Третья строка содержит произведение этих двух чисел
#
# Пример входных данных:
#
# - 21
# - 43
#
# Пример выходных данных:
#
# - 64
# - -22
# - 903

# %%
A = int(input())
B = int(input())

# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано два числа (А, B) типа данных int.
#
# Программа должна вывести две строки где:
# - Первая строка содержит обычного деления чисел A и B
# - Вторая строка содержит результат деления нацело чисел А и B
#
# Пример входных данных:
#
# - 19
# - 2
#
# Пример выходных данных:
#
# - 9.5
# - 9

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (А, B, C) типа данных str.
#
# Программа должна вывести:
# - Есть ли "Bo" в конце первой строки.
# - Есть ли "Bo" в конце второй строки.
# - Есть ли "Bo" в конце третей строки.
#
# Пример входных данных:
#
# - "SuperBo"
# - "phone"
# - "accauntBo123"
#
# Пример выходных данных:
#
# - True
# - False
# - False

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (А, B, C) типа данных str.
#
# Программа должна вывести:
# - Есть ли "key" в начале первой строки.
# - Есть ли "key" в начале второй строки.
# - Есть ли "key" в начале третей строки.
#
# Пример входных данных:
#
# - "key: hjdPwWX92"
# - "number: 433488"
# - "key: dhS73Snka"
#
# Пример выходных данных:
#
# - True
# - False
# - True

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано два числа (А, B) типа данных int.
#
# Программа должна поменять местами значения переменных и вывести их на экран. (Использование третьей переменной не требуется)
#
# Пример входных данных:
#
# - 840
# - 128
#
# Пример выходных данных:
#
# - 840
# - 128

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны три числа (А, B, C) в типе данных int.
#
# Программа должна вывести на экран:
# - Остаток от деления числа А на число B
# - Остаток от деления числа А на число B
#
# Пример входных данных:
#
# - 4573
# - 121
# - 23
#
# Пример выходных данных:
#
# - 96
# - 19

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано две строки (А, B) в типе данных str.
#
# Программа должна:
# - Вывести первую строку на экран в верхнем регистре
# - Вывести вторую строку на экран с заглавной буквы
#
# Пример входных данных:
#
# - "bigString"
# - "iNteLliGeNcE"
#
#
# Пример выходных данных:
#
# - "BIGSTRING"
# - "Intelligence"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано четыре строки (А, B, C, D) типа данных str.
#
# Программа должна найти индекс начала и конца фразы "book" в каждой из строк и вывести их на экран.
#
# Пример входных данных:
#
# - "Bookshelf"
# - "firstBookEver"
# - "BigBook"
# - "underratedBook"
#
# Пример выходных данных:
#
# - 0, 4
# - 5, 9
# - 3, 7
# - 10, 14

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны четыре числа (А, B, C, D) типа данных int.
#
# Программа должна найти и вывести на экран:
# - Число A в степени B
# - Число C в степени D
# - Число D в степени A
#
# Пример входных данных:
#
# - 37
# - 3
# - 96
# - 5
#
# Пример выходных данных:
#
# - 50653
# - 8153726976
# - 72759576141834259033203125

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (А, B, C) в типе данных str.
#
# Программа должна обрезать строки пополам и вывести первую половину на экран. (Используй срезы и деление нацело)
#
# Пример входных данных:
#
# - "firstSmallPanda"
# - "SecondSmallPanda"
# - "BigPanda"
#
# Пример выходных данных:
#
# - "firstSm"
# - "SecondSm"
# - "BigP"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (A, B, C) в типе данных str.
#
# Программа должна найти индекс последнего "string" в строке и вывести его на экран.
#
# Пример входных данных:
#
# - "string string string string string"
# - "string string string string string string string string string string string"
# - "string string"
#
# Пример выходных данных:
#
# - 28
# - 70
# - 7

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано два числа (A, B) в типе данных int.
#
# Программа должна определить четное число или нет. Если число четное, программа выводит на экран "четное", иначе программа выводит на экран "нечетное".
#
# Пример входных данных:
#
# - 23
# - 46
#
# Пример выходных данных:
#
# - "Нечетное"
# - "Четное"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны две строки (A, B) в типе данных str.
#
# Программа должна проверить, есть ли символ '&' внутри строки, если есть, программа должна заменить его на '%'. Если такого символа нет, программа добавляет один такой символ в конец.
#
# Пример входных данных:
#
# - "testStringFfFBbB"
# - "password&nnnFFF"
#
# Пример выходных данных:
#
# - "testStringFfFBbB&"
# - "password%nnnFFF"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дана одна строка (А) в типе данных str.
#
# Программа должна проверять:
# - Если в строке есть слово "login", то программа должна вывести на экран "Это логин."
# - Иначе если в строке есть слово "password", то программа должна вывести "Это пароль."
# - Иначе программа должна вывести "Ошибка!"
#
# Пример входных данных:
#
# - "password: 23135431"
#
#
# Пример выходных данных:
#
# - "Это пароль."

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны две строки (A, B) в типе данных str.
#
# Программа должна вывести на экран самую длинную строку, если строки равны по длине, программа должны вывести обе.
#
# Пример входных данных:
#
# - "qwerty"
# - "qwertyuiop"
#
# Пример выходных данных:
#
# - "qwertyuiop"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны две строки (A, B) в типе данных str.
#
# Программа должна проверять:
#
# - Если длина строки A больше длине строки B, то программа выводит на экран разность длин (длина строки А - длина строки B)
# - Иначе если длина строки A меньше длины строки B, то программа выводит на экран сумму длин строк (длина строки А + длина строки B)
#
# - Иначе программа проверяет:
#     - Если первый символ строки A такой же, как первый символ строки B, то программа склеивает строки и выводит на экран
#     - Иначе программа выводит первый символ строки A и последний символ строки B
#
# Примеры входных данных:
#
# 1)
#     - "------------"
#     - "-------"
#
# 2)
#     - "********"
#     - "********"
#
# Примеры выходных данных:
#
# 1)
#     - 5
#
# 2)
#     - "****************"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (A, B, C) в типе данных str.
#
# Программа должна проверять наличие ключевого слова "дерево" в каждой из строк. Если каждая из строк имеет в себе это ключевое слово, программа должна выводить на экран True, иначе программа должна выводить False. (Нужно использовать and)
#
# Пример входных данных:
#
# - "Дуб: дерево"
# - "Малина: ягода"
# - "Ель: дерево"
#
# Пример выходных данных:
#
# - False

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано три строки (A, B, C) в типе данных str.
#
# Программа должна проверять:
# - Содержит ли первая строка только цифры, если да, то программа должна перевести строку в int.
# - Содержит ли вторая строка только цифры, если да, то программа должна перевести строку в int.
# - Содержит ли третья строка только цифры, если да, то программа должна перевести строку в int.
#
# Программа должна вывести на экран только то что она ранее перевела в int.
#
# Пример входных данных:
#
# - "O092JK"
# - "823822"
# - "#233F2"
#
# Пример выходных данных:
#
# - 823822
#
# (Для решения задачи нужно использовать метод isnumeric)

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Даны три числа (A, B, C) в типе данных float.
#
# Программа должна проверить какой из нижеприведённых сценариев будет верным:
#
# 1. A > B > C
# 2. C > B > A
# 3. B > C > A
# 4. C > A > B
# 5. B > A > C
#
# Программа после проверки должна вывести номер сценария (от 1 до 5).
#
# Если ни один из вышеописанных сценариев не подошел, программа должна вывести "Такого сценария нет в программе".
#
# Пример входных данных:
#
# - 423.12
# - 431.1
# - 21.2
#
# Пример выходных данных:
#
# - 5

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано две строки (A, B) в типе данных str.
#
# Программа должна уровнять длину этих строк, то есть, если длина строки A равна 21, а длина строки B равна 15 программа должна дополнить строку B последним символом строки A. В конце программа должна вывести обе строки.
#
# Пример входных данных:
#
# - "string with exstra symbols"
# - "string"
#
# Пример выходных данных:
#
# - "string with exstra symbols"
# - "stringssssssssssssssssssss"

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Программа должна начинаться с бесконечного цикла и иметь внутри себя ввод, если во введенной строке, есть символ "@" и при этом нет символа "/" то программа завершает свою работу, иначе продолжает.

# %%
# твой код

# %% [markdown]
# ---

# %% [markdown]
# **Реши задачу**
#
# Дано два числа (A, B) в типе данных int.
#
# Программа должна иметь в себе бесконечный цикл и работать до тех пор, пока число B, не станет меньше числа A. (На каждом кругу цикла от числа B отнимется 1)
# В конце программа должна вывести количество повторений которые она выполнила.
#
# Примеры входных данных:
#
# - 52
# - 120
#
# Примеры выходных данных:
#
# - 68
#
# (Задачу обязательно нужно решить используя цикл)

# %%
# твой код

# %% [markdown]
# ---
